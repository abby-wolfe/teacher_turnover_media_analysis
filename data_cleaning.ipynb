# %%
import glob
from striprtf.striprtf import rtf_to_text
import re
import pandas as pd
import datetime
import numpy as np
import os

# %%
file_name = []
for rtf in glob.glob('data/extracted_docs/*.rtf'):
    #print(rtf)
    file_name.append(rtf)

# %%
file_name
# Out:
# ["data/extracted_docs\\'A momentous decision'_ What the resolution of Detroit's literacy case could mean for America.rtf",
#  "data/extracted_docs\\'A nice uplift for the community'; Fort Chipewyan school receives provincial funding for modernizati.rtf",
#  "data/extracted_docs\\'A societal crisis'_ Does this UMKC program have the solution to teacher retention_.rtf",
#  "data/extracted_docs\\'Abbott Elementary' School veteran shares what's real, what's not in Philly-set show.rtf",
#  "data/extracted_docs\\'FALL INTO TEACHING' EVENT CELEBRATES BOOK RELEASE, PROMOTES SELF-CARE.rtf",
#  "data/extracted_docs\\'I'm looking to re-energize and build'_ Clarksdale schools new leader accepts 'the unique set of cha.rtf",
#  "data/extracted_docs\\'I'm not going to waste my time on prayers'.rtf",
#  "data/extracted_docs\\'I'm not going to waste my time on prayers'_ how secular teachers navigate working in religious scho(2).rtf",
#  "data/extracted_docs\\'I'm not going to waste my time on prayers'_ how secular teachers navigate working in religious scho(3).rtf",
#  "data/extracted_docs\\'I'm not going to waste my time on prayers'_ how secular teachers navigate working in religious scho.rtf",
#  "data/extracted_docs\\'Intellectual freedom' bill heading to governor, chambers approve budgets, Bright Futures and more.rtf",
#  "data/extracted_docs\\'Is Everybody OK_ Is Everybody Safe_' Coaches find themselves doing so much outside of sports that m.rtf",
#  "data/extracted_docs\\'It makes us better teachers because we're not carrying it inside.' How one Detroit preschool helps.rtf",
#  "data/extracted_docs\\'It's a broken system' 'It's a broken system'_ There's a child care crisis in Virginia. This is what.rtf",
#  "data/extracted_docs\\'Let educators educate'_ Bills causing current, future teachers to reconsider profession.rtf",
#  "data/extracted_docs\\'Pod'-style learning benefits affluent kids and exacerbates education inequality _but it does addres.rtf",
#  "data/extracted_docs\\'School Segregation by Boundary Line in Virginia _ Scope, Significance, State Policy Solutions' Repo.rtf",
#  "data/extracted_docs\\'Stigma is sticky'_ Anna Haskins concludes 'Building an Anti-Racist Vocabulary' series.rtf",
#  "data/extracted_docs\\'Teachers are miserable.' Across New Orleans, schools grapple with teacher shortage.rtf",
#  "data/extracted_docs\\'The Great Exodus'_ Superintendents Resigned in Droves as Culture Wars Hit Schools in 2021.rtf",
#  "data/extracted_docs\\'They're Not Going to Class' Edison High students swipe ID cards when they go into school each day,.rtf",
#  "data/extracted_docs\\'We Need To Be Nurtured, Too'_ Many Teachers Say They're Reaching A Breaking Point.rtf",
#  "data/extracted_docs\\'ZIP Code Has a Gravity'.rtf",
#  'data/extracted_docs\\- Entergy Corporation - Entergy Joins New Orleans Host Committee to Empower New Orleans Teachers.rtf',
#  'data/extracted_docs\\- Georgia State University _ On the Path to Equity.rtf',
#  "data/extracted_docs\\- Hawaii Education Dept._ Waiakea High School 's Whitney Aragaki Named 2022 Hawaii State Teacher of.rtf",
#  "data/extracted_docs\\- University of Virginia _ Uncovering the Legacy of UVA's First Black Woman Graduate.rtf",
#  'data/extracted_docs\\1 in 5 new Texas teachers weren_t certified last year.rtf',
#  'data/extracted_docs\\1.4 million grant builds math momentum with academic partnerships - Gateway.rtf',
#  "data/extracted_docs\\12 ways the last recession changed America 's schools _ and what that means for the years ahead.rtf",
#  'data/extracted_docs\\16 Michigan back-to-school stories with news you can use.rtf',
#  'data/extracted_docs\\1ST REPORT ISSUED ON MICHIGAN PARTNERSHIP MODEL OF SCHOOL REFORM.rtf',
#  'data/extracted_docs\\2019 Florida Charter School Alliance Conference Recap.rtf',
#  'data/extracted_docs\\29 teachers resign from Nashville middle school.rtf',
#  "data/extracted_docs\\3 Education Groups Issue Report Entitled 'Systematic Synthesis of Two Decades of Research'.rtf",
#  'data/extracted_docs\\3 not-quite-true claims about the pandemic and schools.rtf',
#  'data/extracted_docs\\4 ways schools can keep teachers from quitting.rtf',
#  'data/extracted_docs\\4 ways to get more Black and Latino teachers in K-12 public schools(2).rtf',
#  'data/extracted_docs\\4 ways to get more Black and Latino teachers in K-12 public schools(3).rtf',
#  'data/extracted_docs\\4 ways to get more Black and Latino teachers in K-12 public schools.rtf',
#  'data/extracted_docs\\5 big questions for Mayor Lori Lightfoot about Chicago school funding reform.rtf',
#  'data/extracted_docs\\6 education proposals still in the pipeline when Michigan lawmakers left for the summer.rtf',
#  'data/extracted_docs\\70% of teachers are considering leaving their jobs, Texas State Teachers Association survey finds.rtf',
#  'data/extracted_docs\\70% of Texas teachers are considering quitting their jobs, survey finds.rtf',
#  'data/extracted_docs\\85% of district leaders say lack of applicants driving teacher shortages.rtf',
#  "data/extracted_docs\\A Cambridge school that's gone from ordinary to extraordinary(2).rtf",
#  "data/extracted_docs\\A Cambridge school that's gone from ordinary to extraordinary.rtf",
#  'data/extracted_docs\\A closer look at the 14 lowest-performing schools in Hillsborough County The district has 13 schools.rtf',
#  'data/extracted_docs\\A Colorado experiment aims to expand the teacher pipeline.rtf',
#  "data/extracted_docs\\A Descriptive Analysis of University Teachers' Emotional Intelligence, Organizational Commitment, Jo.rtf",
#  'data/extracted_docs\\A LOCAL FIX AND NATIONAL MODEL_ NEW ORLEANS AIMS TO FIX CHILD CARE.rtf',
#  'data/extracted_docs\\A look into the Arizona Teacher Residency program.rtf',
#  'data/extracted_docs\\A peek at educational priorities, school police chiefs, superintendent search, student voting and mo.rtf',
#  'data/extracted_docs\\A POST-PANDEMIC WAVE OF TEACHERS LEAVING THE WORKFORCE, AND OTHER TRENDS.rtf',
#  'data/extracted_docs\\A School District in Fiscal Free-Fall Scrambles to Avoid Crash Landing.rtf',
#  "data/extracted_docs\\A school sitcom, now_ 'Abbott Elementary' makes its case. _Abbott Elementary_ has caught the attenti.rtf",
#  "data/extracted_docs\\A school that's gone from ordinary to extraordinary Number of Grade 6 students meeting Ontario math.rtf",
#  'data/extracted_docs\\A Smart Strategy for Tackling Teacher Shortages.rtf',
#  'data/extracted_docs\\A study on the Impact of Monetary Benefits on Employee Job Satisfaction in Private Schools.rtf',
#  'data/extracted_docs\\A veteran DCPS teacher recaps the school year.rtf',
#  'data/extracted_docs\\A wave of teacher retirements could impact pension funds(2).rtf',
#  'data/extracted_docs\\A wave of teacher retirements could impact pension funds.rtf',
#  'data/extracted_docs\\A year of no excuses I spent a year and a half studying one of the most celebrated and controversial.rtf',
#  'data/extracted_docs\\AAAS RESOURCES FOR STUDENTS_ PREPARING FOR CAREERS IN INNOVATION, COMMUNICATION OR EDUCATION.rtf',
#  'data/extracted_docs\\AACTE LAUNCHES SPECIAL EDUCATION NETWORKED IMPROVEMENT COMMUNITY.rtf',
#  'data/extracted_docs\\AB 2295 Presents Opportunity For Governor To Address Two Major Issues_ Teacher Shortages And Afforda.rtf',
#  'data/extracted_docs\\ADDRESSING TEACHER SHORTAGES WITH DIFFERENTIATED STAFFING MODELS.rtf',
#  'data/extracted_docs\\ADDRESSING THE SPECIAL EDUCATION TEACHER SHORTAGE.rtf',
#  'data/extracted_docs\\AFL aids Greenville County Schools workforce with grant.rtf',
#  'data/extracted_docs\\AFT RESPONDS TO DEPARTMENT OF EDUCATION ON CHARTER SCHOOL REGULATIONS.rtf',
#  "data/extracted_docs\\After a tumultuous year, teacher 'thank you' bonuses gain steam and spark debate.rtf",
#  "data/extracted_docs\\After a year with a new leader, high hopes are giving way to tension within Tennessee 's turnaround.rtf",
#  'data/extracted_docs\\After student walkout, Newark charter school tells some students to stay home.rtf',
#  'data/extracted_docs\\Agency Information Collection Activities; Comment Request; Follow-Up Surveys to the 2020-21 NTPS_ 20.rtf',
#  'data/extracted_docs\\Agency Information Collection Activities; Submission to the Office of Management and Budget for Revi.rtf',
#  'data/extracted_docs\\Aggressive training programs and high wages are breaking the stigma of working in the trades.rtf',
#  'data/extracted_docs\\Aiming at retaining more teachers, Aurora and its union will launch talks with this proposal on pay.rtf',
#  'data/extracted_docs\\AJC AT THE GOLD DOME TEACHER PAY Kemp reiterates vow to pay teachers more, but not when.rtf',
#  "data/extracted_docs\\AJC CONTINUING COVERAGE DEKALB SCHOOLS 'Lame duck' superintendent's tenure ends.rtf",
#  'data/extracted_docs\\AJC CONTINUING COVERAGE DEKALB SCHOOLS Rocky tenure led to school chief exit(2).rtf',
#  'data/extracted_docs\\AJC CONTINUING COVERAGE DEKALB SCHOOLS Rocky tenure led to school chief exit.rtf',
#  'data/extracted_docs\\AJC DIGGING DEEPER EDUCATION Metro schools scramble for special ed teachers.rtf',
#  'data/extracted_docs\\AJC DIGGING DEEPER GWINNETT SCHOOLS Gwinnett schools reach goal_ no teacher vacancies.rtf',
#  'data/extracted_docs\\AJC LOCAL IN-DEPTH EDUCATION Fewer local schools on worst-of list.rtf',
#  'data/extracted_docs\\AJC TOP LOCAL STORY EDUCATION DeKalb school chief Green plans to exit next year.rtf',
#  'data/extracted_docs\\Akron Public Schools short 60 teachers, 30 bus drivers.rtf',
#  'data/extracted_docs\\Alarming Rate of Teacher Turnover in the District Inspires Local Educator to Launch Wellness Program(2).rtf',
#  'data/extracted_docs\\Alarming Rate of Teacher Turnover in the District Inspires Local Educator to Launch Wellness Program(3).rtf',
#  'data/extracted_docs\\Alarming Rate of Teacher Turnover in the District Inspires Local Educator to Launch Wellness Program.rtf',
#  'data/extracted_docs\\Alaska education board reports high teacher turnover Alaska education board reports high teacher tur.rtf',
#  'data/extracted_docs\\Alaska education board reports high teacher turnover(2).rtf',
#  'data/extracted_docs\\Alaska education board reports high teacher turnover.rtf',
#  'data/extracted_docs\\Alaska Gov. Dunleavy Issues State of State Address.rtf',
#  'data/extracted_docs\\Alaska House OKs bill to prevent future teacher layoffs(2).rtf',
#  'data/extracted_docs\\Alaska House OKs bill to prevent future teacher layoffs.rtf',
#  'data/extracted_docs\\Alaska must prepare, attract and retain quality teachers to secure its future Research shows teacher.rtf',
#  'data/extracted_docs\\Alaska Parental Involvement in Education, Ranked.rtf',
#  'data/extracted_docs\\Alaska teachers wonder_ Should they stay or should they go_.rtf',
#  'data/extracted_docs\\Alcohol use more likely among Black youths at racially segregated schools.rtf',
#  'data/extracted_docs\\Alliance for Excellent Education Issues Public Comment on DOEd Notice.rtf',
#  "data/extracted_docs\\American Academy of Pediatrics_ School 'Resegregation' Strongly Associated With Drinking Among Black.rtf",
#  'data/extracted_docs\\American Association for the Advancement of Science _ ARISE Initiative Spurs Research to Improve STE.rtf',
#  'data/extracted_docs\\American Association of Colleges for Teacher Education Launches Special Education Networked Improvem.rtf',
#  'data/extracted_docs\\American College of Emergency Physicians Issues Public Comment on CDC Notice.rtf',
#  "data/extracted_docs\\American Federation of Teachers Issues Report Entitled 'What America Must Do to Attract, Retain the.rtf",
#  'data/extracted_docs\\American Journal of Education Issues 5 Research Articles in November 2019 Edition.rtf',
#  'data/extracted_docs\\American Journal of Education Issues Research Articles in May 2021 Edition.rtf',
#  'data/extracted_docs\\American schools embrace four-day week(2).rtf',
#  'data/extracted_docs\\American schools embrace four-day week(3).rtf',
#  'data/extracted_docs\\American schools embrace four-day week.rtf',
#  "data/extracted_docs\\Amid redistricting debate, Howard officials say students who attend Title I schools 'are simply chil.rtf",
#  'data/extracted_docs\\Amid the nationwide Great Teacher Resignation, Corvallis School District teacher turnover remains lo.rtf',
#  'data/extracted_docs\\An Early Childhood Expert on Reimagining Child Care.rtf',
#  "data/extracted_docs\\An East Tampa charter school offered an alternative. Now it's closing. Envisioned as an option for f.rtf",
#  'data/extracted_docs\\Anchorage School Board candidate Q&As_ Is the Anchorage School District currently doing a good job o.rtf',
#  'data/extracted_docs\\Anchorage School Board candidate Q&A_ Rachel Blakeslee (Seat E) Candidates in the 2021 election for.rtf',
#  "data/extracted_docs\\Andre Agassi fund 'evicts' school after it fails to meet its lease agreement.rtf",
#  'data/extracted_docs\\Angela bows out after 44 years at the same school.rtf',
#  'data/extracted_docs\\Anglum_ A better case for boosting teacher compensation.rtf',
#  'data/extracted_docs\\Another Voice_ Resist alternative programs meant to address teaching shortages.rtf',
#  'data/extracted_docs\\Anson High grows agriculture program(2).rtf',
#  'data/extracted_docs\\Anson High grows agriculture program.rtf',
#  'data/extracted_docs\\AP News Digest 3_50 am.rtf',
#  'data/extracted_docs\\AP News in Brief at 11_04 p.m. EDT(2).rtf',
#  'data/extracted_docs\\AP News in Brief at 11_04 p.m. EDT(3).rtf',
#  'data/extracted_docs\\AP News in Brief at 11_04 p.m. EDT.rtf',
#  'data/extracted_docs\\AP News in Brief at 12_04 a.m. EDT(2).rtf',
#  'data/extracted_docs\\AP News in Brief at 12_04 a.m. EDT.rtf',
#  'data/extracted_docs\\AP News in Brief at 6_04 p.m. EDT(2).rtf',
#  'data/extracted_docs\\AP News in Brief at 6_04 p.m. EDT.rtf',
#  'data/extracted_docs\\AP News in Brief at 9_04 p.m. EDT(2).rtf',
#  'data/extracted_docs\\AP News in Brief at 9_04 p.m. EDT.rtf',
#  'data/extracted_docs\\Applications for New Awards; Personnel Development To Improve Services and Results for Children With.rtf',
#  "data/extracted_docs\\APSU'S CENTER FOR RURAL EDUCATION HELPS RURAL TEACHERS PREPARE FOR NEW SCHOOL YEAR(2).rtf",
#  "data/extracted_docs\\APSU'S CENTER FOR RURAL EDUCATION HELPS RURAL TEACHERS PREPARE FOR NEW SCHOOL YEAR.rtf",
#  "data/extracted_docs\\APSU'S CENTER FOR RURAL EDUCATION TO HOST INAUGURAL CONFERENCE MARCH 23.rtf",
#  "data/extracted_docs\\APSU'S ERIKSSON COLLEGE OF EDUCATION HOSTS 2ND RURAL EDUCATION CONFERENCE.rtf",
#  'data/extracted_docs\\ARISE Initiative Spurs Research to Improve STEM Teacher Training.rtf',
#  'data/extracted_docs\\Arizona Pioneer in Wrecking Public Education through Charter Schools.rtf',
#  'data/extracted_docs\\As kids head back to school, some Charleston teachers start first year in education.rtf',
#  'data/extracted_docs\\As pre-K teachers celebrate pay raises, day care union seizes the moment to reach more schools.rtf',
#  "data/extracted_docs\\As schools try to recover, COVID's toll lingers_ 'We haven't seen fine, ever'.rtf",
#  'data/extracted_docs\\As thousands of third-graders prep for reading retest, districts and literacy coaches work to remove.rtf',
#  'data/extracted_docs\\ASCL ANNUAL CONFERENCE.rtf',
#  "data/extracted_docs\\ASSEMBLY EDUCATION COMMITTEE ADVANCES TWO BILLS TO ADDRESS THE STATE'S TEACHER SHORTAGES(2).rtf",
#  "data/extracted_docs\\ASSEMBLY EDUCATION COMMITTEE ADVANCES TWO BILLS TO ADDRESS THE STATE'S TEACHER SHORTAGES.rtf",
#  "data/extracted_docs\\Audit_ Oregon students with disabilities don't get consistent support.rtf",
#  'data/extracted_docs\\Audit_ Utah keeps teachers overall, but first 5 years tricky.rtf',
#  'data/extracted_docs\\August 10, 2022_ Davenport University_ A Lettinga Legacy - A lifetime of support from Wilbur A. Lett.rtf',
#  'data/extracted_docs\\August 11, 2022_ Syracuse_ Helping Students Succeed_ Addressing Pandemic-Related Learning Loss.rtf',
#  'data/extracted_docs\\AUGUSTA UNIVERSITY KEEPS NEW TEACHING GRADS IN THE CLASSROOM.rtf',
#  'data/extracted_docs\\Aurora Central dodges drastic measures, but state wants it to hire an academic partner.rtf',
#  "data/extracted_docs\\B.C. teacher who went through a buyer's nightmare in Kyuquot finally finds home.rtf",
#  "data/extracted_docs\\B.C. teacher who went through a buyer's nightmare in Kyuquot finds home after the Mirror reported it.rtf",
#  'data/extracted_docs\\Back to school in the Black Belt _ Rural schools embrace new licensing rules to battle teacher short.rtf',
#  'data/extracted_docs\\Back to School Review_ Five Days of Education Policy in Pennsylvania _ Opinion.rtf',
#  'data/extracted_docs\\Being Black in Education_ Where is the system going wrong_.rtf',
#  'data/extracted_docs\\Beshear to propose _historic investments_ for education.rtf',
#  "data/extracted_docs\\Beshear victory voted Kentucky 's top news story of 2019.rtf",
#  "data/extracted_docs\\Betsy DeVos_ Michigan doesn't have enough school choice.rtf",
#  'data/extracted_docs\\Biden Says Schools Must Stay Open, But there Are No Clear Guidelines For Local School Boards.rtf',
#  'data/extracted_docs\\Biden-Harris Administration Announces Public and Private Sector Actions to Strengthen Teaching Profe(2).rtf',
#  'data/extracted_docs\\Biden-Harris Administration Announces Public and Private Sector Actions to Strengthen Teaching Profe.rtf',
#  'data/extracted_docs\\Biochemistry Can Be Elementary.rtf',
#  'data/extracted_docs\\BIPARTISAN BILL WILL IMPROVE STEM EDUCATION IN RURAL AREAS - NOV 6, 2019.rtf',
#  'data/extracted_docs\\Bipartisan Bill Will Improve STEM Education in Rural Areas Rep. Frank Lucas (R- OK ) News Release.rtf',
#  'data/extracted_docs\\Bipartisan Bill Will Improve STEM Education in Rural Areas(2).rtf',
#  'data/extracted_docs\\Bipartisan Bill Will Improve STEM Education in Rural Areas(3).rtf',
#  'data/extracted_docs\\BIPARTISAN BILL WILL IMPROVE STEM EDUCATION IN RURAL AREAS.rtf',
#  'data/extracted_docs\\Bismarck police struggle to recruit, retain officers.rtf',
#  'data/extracted_docs\\Bitterly divided House panel OKs big school voucher bill.rtf',
#  'data/extracted_docs\\Black and male teachers score lower on observations despite similar qualifications.rtf',
#  'data/extracted_docs\\Black teachers more likely to be highly qualified, clock fewer years in classroom.rtf',
#  'data/extracted_docs\\Bleach lives its moment of glory.rtf',
#  'data/extracted_docs\\Board of Education discusses student cellphone use.rtf',
#  'data/extracted_docs\\BOISE STATE RESEARCH INCREASES TEACHER RETENTION RATES IN IDAHO.rtf',
#  'data/extracted_docs\\Booker Re-Introduces Legislation to Boost Teacher Compensation by up to $15,000 Under the RAISE Act,.rtf',
#  'data/extracted_docs\\Booker Re-Introduces Legislation to Boost Teacher Compensation by up to $15,000.rtf',
#  'data/extracted_docs\\Boost student achievement in New Mexico.rtf',
#  'data/extracted_docs\\Born smarter.rtf',
#  "data/extracted_docs\\Boulder Valley school board hears update on district's special education improvements.rtf",
#  'data/extracted_docs\\Briefly Stated_ February 3, 2021(2).rtf',
#  'data/extracted_docs\\Briefly Stated_ February 3, 2021.rtf',
#  'data/extracted_docs\\Briefly Stated_ January 12, 2022.rtf',
#  'data/extracted_docs\\Briefly Stated_ September 21, 2022.rtf',
#  'data/extracted_docs\\Bringhurst_ Utah Lawmakers Should Prioritize Teachers in High Poverty Schools.rtf',
#  'data/extracted_docs\\BUDGETING DURING AND FOR RECOVERY.rtf',
#  'data/extracted_docs\\BUILDING TRAUMA-INFORMED SCHOOL SYSTEMS.rtf',
#  'data/extracted_docs\\Bulletin Board.rtf',
#  "data/extracted_docs\\Burton_ Teachers Can't Succeed In Their Classrooms On Bonuses Alone.rtf",
#  'data/extracted_docs\\California data shows 83% of teachers have proper credentials.rtf',
#  'data/extracted_docs\\California School Boards Association_ Governor Notches Victories On Affordable Housing And The Teach.rtf',
#  'data/extracted_docs\\California Teachers Association Announces 13 Winners of John Swett Awards Honoring Media Coverage of.rtf',
#  'data/extracted_docs\\CAN A PERSON-CENTERED APPROACH TO PROFESSIONAL DEVELOPMENT HELP RETAIN TEACHERS_.rtf',
#  'data/extracted_docs\\Can aggressive oversight change the fortunes of this Detroit charter school_.rtf',
#  'data/extracted_docs\\Can Bite-Sized Lessons Make Social-Emotional Learning Easier to Teach_.rtf',
#  'data/extracted_docs\\Can Deregulated Charter Schools Not Be Deregulated Charter Schools_.rtf',
#  'data/extracted_docs\\Canada _ Support for Conklin and Fort Chipewyan schools.rtf',
#  'data/extracted_docs\\Canadian English language sector battles teacher shortage.rtf',
#  'data/extracted_docs\\CANDIDATE Q&A_ Governor - Les Gara.rtf',
#  'data/extracted_docs\\CANDIDATE Q&A_ Governor _ Les Gara.rtf',
#  'data/extracted_docs\\Candidate Q&A_ State House District 41 _ Matt LoPresti.rtf',
#  'data/extracted_docs\\CANDIDATES FOR OPEN SEAT BOTH TOUT THEIR PERSONAL EXPERIENCE MADISON SCHOOL BOARD _ SEAT 6.rtf',
#  'data/extracted_docs\\Caprabo grows for the first time in five years, to 842 million.rtf',
#  'data/extracted_docs\\Cardona urges support for educators as rocky year comes to a close.rtf',
#  'data/extracted_docs\\Cash-strapped US schools facing teacher recruitment crisis adopt four-day week.rtf',
#  "data/extracted_docs\\Casino workers' union joins rally for collective bargaining.rtf",
#  "data/extracted_docs\\Center for American Progress_ 'How To Ensure Equitable Access to Great Teaching'.rtf",
#  "data/extracted_docs\\Center for American Progress_ 'Social and Emotional Supports for Educators During and After Pandemic.rtf",
#  'data/extracted_docs\\Center on Budget and Policy Priorities_ Research Shows Rental Assistance Reduces Hardship and Provid.rtf',
#  'data/extracted_docs\\Central leaders, parents discuss concerns.rtf',
#  "data/extracted_docs\\CERES Institute for Children and Youth Issues White Paper Entitled 'Supporting Students With Learnin.rtf",
#  'data/extracted_docs\\Chairman Gregorio Sablan Issues Statement at Hearing on Educating Educators.rtf',
#  'data/extracted_docs\\Chaos in Kenosha _ A UW Oshkosh alumnus shares experience on the ground.rtf',
#  'data/extracted_docs\\Character, academics in focus.rtf',
#  'data/extracted_docs\\Charter School Advocates Are Hypocritical and Out-of-Touch.rtf',
#  'data/extracted_docs\\Charter School Advocates Grow More Belligerent.rtf',
#  'data/extracted_docs\\Charter School Advocates Reject Analysis.rtf',
#  'data/extracted_docs\\Charter School Advocates Repulsed by Empowered Teachers.rtf',
#  'data/extracted_docs\\Charter School Apologia.rtf',
#  'data/extracted_docs\\Charter School Fatigue.rtf',
#  'data/extracted_docs\\Charter School Fictions and Grandstanding.rtf',
#  'data/extracted_docs\\Charter School Promoters Celebrate Charter School Failure.rtf',
#  'data/extracted_docs\\Charter School Promoters Loathe Public Authority and Intensify Lawlessness, Threats, and Bully Tacti.rtf',
#  'data/extracted_docs\\Charter School Transparency and Accountability Remain Low.rtf',
#  'data/extracted_docs\\Charter Schools Have Fewer Nurses and More Inexperienced Teachers than Public Schools.rtf',
#  'data/extracted_docs\\Charter Schools Have No Legitimate Claim to Public Funds.rtf',
#  "data/extracted_docs\\Charter Schools' Obsession With Test Scores Deliberately Misses the Point.rtf",
#  "data/extracted_docs\\Charter Schools_ 'Choice' Is Not An Argument.rtf",
#  'data/extracted_docs\\Charter union leaders say remote learning requires new union agreements. Not all schools are complyi.rtf',
#  'data/extracted_docs\\Chicago Public Schools have lost 25,000 students since COVID-19 hit.rtf',
#  'data/extracted_docs\\Chicago Teachers Union Passages Charter Strikers to Protest Charter Operator Greed at High-Rent Fund.rtf',
#  "data/extracted_docs\\Chile 's fiasco in making all temporary teachers permanent and the lesson for Spain.rtf",
#  "data/extracted_docs\\China's international schools face dire fate if zero-Covid drives away teachers, BritCham warns.rtf",
#  'data/extracted_docs\\Chisholm school board candidates concerned about turnover, giving teachers a voice.rtf',
#  'data/extracted_docs\\Christopherson_ Utah Must Implement a Statewide Training Program to End a Teacher Shortage Crisis.rtf',
#  'data/extracted_docs\\CLASS ACTS_ THE PUBLIC SERVANTS.rtf',
#  "data/extracted_docs\\CLASSROOM _EXODUS' EDUCATION SCHOOLS GRAPPLE WITH FINDING THE NEXT GENERATION OF TEACHERS AS MORE LE.rtf",
#  'data/extracted_docs\\ClassTag Announces $20,000 in Grants for Teachers to Transform Their Classrooms The ClassTag Transfo.rtf',
#  'data/extracted_docs\\Classtag Announces $20,000 In Grants For Teachers To Transform Their Classrooms(2).rtf',
#  'data/extracted_docs\\ClassTag Announces $20,000 in Grants for Teachers to Transform Their Classrooms(3).rtf',
#  'data/extracted_docs\\ClassTag Announces $20,000 in Grants for Teachers to Transform Their Classrooms(4).rtf',
#  'data/extracted_docs\\ClassTag Announces $20,000 in Grants for Teachers to Transform Their Classrooms(5).rtf',
#  'data/extracted_docs\\ClassTag Announces $20,000 in Grants for Teachers to Transform Their Classrooms.rtf',
#  'data/extracted_docs\\ClassTag Announces Grants for Teachers.rtf',
#  'data/extracted_docs\\Cleveland charter school uses public dollars to fight union drive.rtf',
#  'data/extracted_docs\\Closing the Opportunity Gap_ How Positive Outlier Districts in California Are Pursuing Equitable Acc.rtf',
#  'data/extracted_docs\\Co-Teaching_ Valuable But Hard to Get Right.rtf',
#  'data/extracted_docs\\Coalition for Teaching Quality Issues Public Comment on DOEd Notice.rtf',
#  'data/extracted_docs\\Coalition for Teaching Quality Issues Public Comment on DOEd Proposed Rule.rtf',
#  'data/extracted_docs\\College presidents head for the exits.rtf',
#  "data/extracted_docs\\Colorado 's state board gives Aurora Central one year to improve its ratings.rtf",
#  'data/extracted_docs\\Colorado education budget increases did not translate to higher teacher pay_ Report.rtf',
#  "data/extracted_docs\\Colorado has more than 100 innovation schools. State officials want to know how they're doing.rtf",
#  "data/extracted_docs\\Columbia school district's spending on black-tie gala questioned amid empty teacher slots.rtf",
#  'data/extracted_docs\\Commentary_ Pandemic prompts more teachers to consider early retirement or newcareer.rtf',
#  'data/extracted_docs\\Community Partnerships Can Be Vital To Schools _ And Hard To Sustain.rtf',
#  "data/extracted_docs\\Community rallies around Memphis' Kingsbury after 'fresh start'.rtf",
#  'data/extracted_docs\\Concerns raised about staff changes at some Houston schools.rtf',
#  'data/extracted_docs\\Concordia College _ Future Math Teachers to Benefit From $1.2 Million Grant.rtf',
#  'data/extracted_docs\\CONGRESSMAN SCHIFF, SENATOR BOOKER INTRODUCE LEGISLATION TO BOOST TEACHER COMPENSATION Rep. Adam Sch.rtf',
#  'data/extracted_docs\\CONGRESSMAN SCHIFF, SENATOR BOOKER INTRODUCE LEGISLATION TO BOOST TEACHER COMPENSATION.rtf',
#  'data/extracted_docs\\CORI BUSH ANNOUNCES DISTRIBUTION OF AMERICAN RESCUE PLAN FUNDING FOR MISSOURI SCHOOLS AND STUDENTS.rtf',
#  'data/extracted_docs\\Council delves into school problems.rtf',
#  'data/extracted_docs\\Council for Exceptional Children Issues Public Comment on DOEd Notice.rtf',
#  'data/extracted_docs\\Countryside focuses on character as well as academic performance.rtf',
#  'data/extracted_docs\\County School Board mandates the wearing of masks indoors and on buses when classes resume.rtf',
#  'data/extracted_docs\\COUNTYWIDE Few specifics on special-ed vacancy posts.rtf',
#  'data/extracted_docs\\COUNTYWIDE Special education teacher vacancies cut instead of filled.rtf',
#  'data/extracted_docs\\COUNTYWIDE Teacher-certification agency investigating schools chief.rtf',
#  'data/extracted_docs\\COVID disruptions hurt student progress at all grade levels, GAO says.rtf',
#  'data/extracted_docs\\Covid relief money to fund new teacher program.rtf',
#  'data/extracted_docs\\Crane awarded state grant.rtf',
#  'data/extracted_docs\\Crow Tribe journalism teacher seeks stories no one tells(2).rtf',
#  'data/extracted_docs\\Crow Tribe journalism teacher seeks stories no one tells(3).rtf',
#  'data/extracted_docs\\Crow Tribe journalism teacher seeks stories no one tells(4).rtf',
#  'data/extracted_docs\\Crow Tribe journalism teacher seeks stories no one tells.rtf',
#  'data/extracted_docs\\Crowd shows support for Central principal at school board meeting.rtf',
#  'data/extracted_docs\\D.C. schools are losing educators. Teachers have solutions.rtf',
#  'data/extracted_docs\\D.C. teachers are burning out.rtf',
#  'data/extracted_docs\\D.C. Voter Guide_ Meet the candidates for mayor, attorney general and council chair.rtf',
#  'data/extracted_docs\\Dallas ISD_ Many Teachers Could See Notable Salary Increases Thanks to TEI and Related State Funding.rtf',
#  'data/extracted_docs\\David Osborne Keeps Casually Peddling Worn-Out Charter School Disinformation.rtf',
#  'data/extracted_docs\\Deborah Gatrell Utah lawmakers put a destructive frame around tax reform.rtf',
#  'data/extracted_docs\\DECISION THIS WEEK ON CITY SCHOOL SHAKE-UP.rtf',
#  'data/extracted_docs\\DeKalb County (Ga.) district severs ties with superintendent, names interim leader.rtf',
#  "data/extracted_docs\\DeKalb school board District 2_ Four candidates want Orson's open seat.rtf",
#  'data/extracted_docs\\Del. Sablan Introduces Elevation of Education Profession Act.rtf',
#  'data/extracted_docs\\Del. Sablan_ In-State Tuition for Marianas Students in College Affordability Act.rtf',
#  'data/extracted_docs\\Democratic candidates talk education, preview of session and teacher pay, contract impasse and more.rtf',
#  'data/extracted_docs\\Democrats Long-time Supporters of Charter Schools.rtf',
#  "data/extracted_docs\\Department of Education Issues Commentary Entitled 'Top Five Takeaways for Supporting Teacher Leader.rtf",
#  'data/extracted_docs\\Department of Education_ The Most Meaningful Way to Celebrate Your Teacher.rtf',
#  'data/extracted_docs\\DeSantis signs Parental Rights in Education bill, another superintendent stepping aside, and more.rtf',
#  "data/extracted_docs\\Despite pandemic, there's little evidence of rising teacher turnover _ yet.rtf",
#  'data/extracted_docs\\Despite pandemic-related stress, many teachers stay put.rtf',
#  'data/extracted_docs\\DESPITE STRESS, MANY TEACHERS STAY ON JOB PANDEMIC IMPACTS _ K-12 EDUCATION.rtf',
#  'data/extracted_docs\\Despite stress, many teachers stay on the job.rtf',
#  'data/extracted_docs\\Detroit district making fixes to virtual school.rtf',
#  'data/extracted_docs\\Detroit schools almost fully staffed as new year begins.rtf',
#  'data/extracted_docs\\DeVos Plan For More Pay-The-Rich Charter Schools.rtf',
#  'data/extracted_docs\\Diane B Hirshberg(2).rtf',
#  'data/extracted_docs\\Diane B Hirshberg.rtf',
#  'data/extracted_docs\\Did Indianapolis students do better after struggling schools were restarted_ A new study takes a loo.rtf',
#  'data/extracted_docs\\DINAPOLI_ 23 SCHOOL DISTRICTS DESIGNATED IN FISCAL STRESS.rtf',
#  'data/extracted_docs\\DINAPOLI_ 31 SCHOOL DISTRICTS DESIGNATED IN SOME LEVEL OF FISCAL STRESS.rtf',
#  'data/extracted_docs\\Director leaves North Side Community charter school after tumultuous year.rtf',
#  'data/extracted_docs\\Discounts on school monthly payments spend first debate.rtf',
#  'data/extracted_docs\\Disgusted by abuse and politicization, many school superintendents considered quitting last year(2).rtf',
#  'data/extracted_docs\\Disgusted by abuse and politicization, many school superintendents considered quitting last year.rtf',
#  'data/extracted_docs\\Districts prepare for start of new school year with various staff hiring needs.rtf',
#  'data/extracted_docs\\Do charter schools make segregation worse_.rtf',
#  'data/extracted_docs\\Do High-Stakes Tests Make Teachers More Likely to Quit_ Study Says No.rtf',
#  'data/extracted_docs\\DOE Plan Would Boost Pay For Hard-To-Fill Teaching Positions.rtf',
#  "data/extracted_docs\\DOEd Approves Missouri 's Plan for Use of American Rescue Plan Funds to Support K-12 Schools, Studen.rtf",
#  'data/extracted_docs\\DOEd_ Applications for New Awards for Personnel Development To Improve Services and Results for Chil.rtf',
#  'data/extracted_docs\\DOEd_ Applications for New Awards for Promise Neighborhoods Program.rtf',
#  'data/extracted_docs\\DOEd_ Applications for New Awards of Full-Service Community Schools Program.rtf',
#  'data/extracted_docs\\DOEd_ Final Priorities, Requirements, Definitions, Selection Criteria-Full-Service Community Schools.rtf',
#  'data/extracted_docs\\DOEd_ Personnel Development To Improve Services, Results for Children With Disabilities-Improving Re.rtf',
#  'data/extracted_docs\\DOEd_ Promise Neighborhoods Program.rtf',
#  'data/extracted_docs\\Does Managerial Use of Performance Information Matter to Organizational Outcomes_.rtf',
#  'data/extracted_docs\\Dogged by money trouble and low enrollment, Tindley will downsize its charter network.rtf',
#  'data/extracted_docs\\Dom Amore_ Jim Mora, UConn get the win they needed, and deserve to feel good about it.rtf',
#  "data/extracted_docs\\Don't Be Charter-Fooled.rtf",
#  "data/extracted_docs\\Don't Blame Trump, DeVos, or Unions for Growing Opposition to Charter Schools.rtf",
#  "data/extracted_docs\\Don't let political division obscure our urban-rural ties Margaret Cowell and Sarah Lyon-Hill column.rtf",
#  'data/extracted_docs\\Dougherty educator Debra Wiley in second race for District 2 School Board seat.rtf',
#  'data/extracted_docs\\Dougherty School System researching date for swearing in newly elected school board member.rtf',
#  'data/extracted_docs\\Duckworth, Durbin Call for Increased Funding for the Education Workforce Amid COVID-19 Pandemic.rtf',
#  'data/extracted_docs\\Dueling conferences offer distinct messages on future of Florida education A roundup of Florida educ.rtf',
#  'data/extracted_docs\\Dunleavy administration pursues partnering with tribes for public education - and wants your input A.rtf',
#  'data/extracted_docs\\Dunleavy administration pursues partnering with tribes for public education.rtf',
#  'data/extracted_docs\\DuPage Regional Office of Education Issues Public Comment on DOEd Proposed Rule.rtf',
#  'data/extracted_docs\\Early childhood education training needs investment, higher ed leaders say(2).rtf',
#  'data/extracted_docs\\Early childhood education training needs investment, higher ed leaders say.rtf',
#  "data/extracted_docs\\Early Retired Teachers' Perspectives on Leisure Time and Educational Activities_ A Way Forward for R.rtf",
#  'data/extracted_docs\\East Tennessee State University _ Galyon Is Incoming Chair of National Organization on Rural Special.rtf',
#  'data/extracted_docs\\Eastern Michigan University , in Partnership With Washtenaw Intermediate School District , Chosen as.rtf',
#  "data/extracted_docs\\Economic Policy Institute Report_ 'Examining Factors That Play Role in Teacher Shortage Crisis'.rtf",
#  'data/extracted_docs\\Economic Policy Institute_ Raising Pay in Public K-12 Schools Is Critical to Solving Staffing Shorta.rtf',
#  'data/extracted_docs\\ECW Interviews the Honourable Awut Deng Acuil, Minister of General Education and Instruction for Sou.rtf',
#  'data/extracted_docs\\Editorial Roundup_ New England.rtf',
#  'data/extracted_docs\\Editorial_ Richmond should hold a citywide summit to address the root causes of crime.rtf',
#  'data/extracted_docs\\Education & Urban Society Journal Issues Research Articles in February 2022 Edition.rtf',
#  'data/extracted_docs\\Education chief resigns as new board discusses removal.rtf',
#  'data/extracted_docs\\Education choice is the best way to weed out lackluster teachers.rtf',
#  'data/extracted_docs\\EDUCATION COMMISSIONER GLASS DISCUSSES TEACHER SHORTAGES WITH INTERIM JOINT COMMITTEE ON EDUCATION.rtf',
#  'data/extracted_docs\\Education Department Seeks Public Comment on Info Collection_ Teacher Follow-Up Survey, Principal Fo.rtf',
#  'data/extracted_docs\\Education Guide 2021_ Charter schools seek clarity after year of unknowns_.rtf',
#  'data/extracted_docs\\Education majors and faculty_ COVID-19 not only cause for teacher shortage.rtf',
#  "data/extracted_docs\\Education Minister visiting Conklin , Fort Chip after council discusses 'educational crisis'.rtf",
#  'data/extracted_docs\\Education Minister visiting Conklin , Fort Chip.rtf',
#  'data/extracted_docs\\Education Partnership talks POWER bag initiative.rtf',
#  'data/extracted_docs\\Education Trust Comments on Proposed Priorities and Definitions for Discretionary Grants Programs.rtf',
#  'data/extracted_docs\\Education Trust Issues Public Comment on DOEd Proposed Rule.rtf',
#  'data/extracted_docs\\Educational Administration Quarterly Journal Issues Research Articles in February 2022 Edition.rtf',
#  'data/extracted_docs\\Educational Evaluation & Policy Analysis Journal Issues Research Articles in March 2021 Edition.rtf',
#  'data/extracted_docs\\Educators for Excellence Reacts to the Passage of the Federal Stimulus Bill.rtf',
#  "data/extracted_docs\\Educators for Excellence- Connecticut Reacts to Governor Lamont's Student Loan Subsidy Program.rtf",
#  'data/extracted_docs\\Educators for Excellence_ Coalition Demands Education Relief Package Targeted Toward Students, Teach.rtf',
#  "data/extracted_docs\\Educators Nationwide Can Spring into Wellness with Free Well-Being Supports From Rethink Ed Rethink'.rtf",
#  "data/extracted_docs\\Educators of Color Cite 'Invisible Tax' _If You Listen, We Will Stay_ Why Teachers of Color Leave an.rtf",
#  "data/extracted_docs\\EDUCATORS' POOR MORALE MATTERS, EVEN IF THEY DON'T QUIT. HERE'S WHY.rtf",
#  'data/extracted_docs\\Educators_ A profession in crisis.rtf',
#  'data/extracted_docs\\Effects of Monetary Incentives on Teacher Turnover_ A Longitudinal Analysis.rtf',
#  'data/extracted_docs\\Eight lessons we learned from education research in 2019.rtf',
#  'data/extracted_docs\\ELECTION 2020 _ EDGERTON SCHOOL BOARD.rtf',
#  'data/extracted_docs\\Election 2020, Gilroy Unified School District _ Retired teacher brings inner knowledge of district.rtf',
#  'data/extracted_docs\\Elevating Teacher Voices, Along with Their Salaries to Professionalize Teaching in Louisiana.rtf',
#  'data/extracted_docs\\ELEVATION OF THE EDUCATION PROFESSION ACT; Congressional Record Vol. 165, No. 151 (Extensions of Rem.rtf',
#  'data/extracted_docs\\Eliminating High-Stakes Testing May Not Lessen Most Teacher Turnover _Testing, Teacher Turnover, and.rtf',
#  'data/extracted_docs\\Elior Group_ Results; Objectives for the 2018-2019 financial year completed; New Elior ambitions con.rtf',
#  'data/extracted_docs\\Enrollment losses in cities prompt talk of school closures.rtf',
#  'data/extracted_docs\\Entergy Joins New Orleans Host Committee to Empower New Orleans Teachers(2).rtf',
#  'data/extracted_docs\\Entergy Joins New Orleans Host Committee to Empower New Orleans Teachers(3).rtf',
#  'data/extracted_docs\\Entergy Joins New Orleans Host Committee to Empower New Orleans Teachers(4).rtf',
#  'data/extracted_docs\\Entergy Joins New Orleans Host Committee to Empower New Orleans Teachers(5).rtf',
#  'data/extracted_docs\\Entergy Joins New Orleans Host Committee to Empower New Orleans Teachers(6).rtf',
#  'data/extracted_docs\\Entergy Joins New Orleans Host Committee to Empower New Orleans Teachers.rtf',
#  "data/extracted_docs\\Entrepreneurship education won't save the teaching profession _ but it's a good place to start.rtf",
#  'data/extracted_docs\\Eric Adams keeps mayoral control, must lower class size.rtf',
#  "data/extracted_docs\\Eric Stinton_ Schools Don't Cause Societal Tensions But They Can Address Them.rtf",
#  'data/extracted_docs\\European Journal of Education Issues Research Articles in March 2021 Edition.rtf',
#  'data/extracted_docs\\EVENT Nov. 20-22, 2019_ Virginia School Boards Association Schedules Annual Convention.rtf',
#  "data/extracted_docs\\Every 4-year-old in Colorado can attend preschool for free in '23. Will Utah follow_(2).rtf",
#  "data/extracted_docs\\Every 4-year-old in Colorado can attend preschool for free in '23. Will Utah follow_.rtf",
#  'data/extracted_docs\\Exceptional Children Journal Issues Research Articles in July 2022 Edition.rtf',
#  'data/extracted_docs\\Exhausted. Stressed. Frustrated. Teachers are burned out.rtf',
#  'data/extracted_docs\\Eyes on school staffing, student attendance, and behavior this year.rtf',
#  'data/extracted_docs\\FACT SHEET_ Biden-_Harris Administration Announces Public and Private Sector Actions to Strengthen T.rtf',
#  "data/extracted_docs\\Fairbanks teacher recruitment_ 'Turning over every stone'(2).rtf",
#  "data/extracted_docs\\Fairbanks teacher recruitment_ 'Turning over every stone'.rtf",
#  'data/extracted_docs\\Fairfield and Greenville County School Districts Stand Out Nationally in Teacher Engagement Growth F.rtf',
#  'data/extracted_docs\\Fairfield and Greenville County School Districts Stand Out Nationally in Teacher Engagement Growth.rtf',
#  'data/extracted_docs\\Families of students with disabilities raise concerns about school reopening.rtf',
#  'data/extracted_docs\\Federal Register_ Agency Information Collection Activities; Comment Request; Follow-Up Surveys to th.rtf',
#  'data/extracted_docs\\Federal Register_ Agency Information Collection Activities; Submission to the Office of Management a.rtf',
#  'data/extracted_docs\\Federal Register_ Applications for New Awards; Mental Health Service Professional Demonstration Gran.rtf',
#  'data/extracted_docs\\Federal Register_ Applications for New Awards; Personnel Development To Improve Services and Results.rtf',
#  'data/extracted_docs\\Federal Register_ Applications for New Awards; Promise Neighborhoods (PN) Program Pages 38719 - 3872.rtf',
#  'data/extracted_docs\\Federal Register_ Applications for New Awards; Promise Neighborhoods (PN) Program Pages 5154 - 5163.rtf',
#  'data/extracted_docs\\Federal Register_ Applications for New Awards; Teacher Quality Partnership Grant Program Pages - 297.rtf',
#  'data/extracted_docs\\Federal Register_ Applications for New Awards; Teacher Quality Partnership Grant Program Pages 10906.rtf',
#  "data/extracted_docs\\Federal Register_ Final Priorities and Definitions-Secretary's Supplemental Priorities and Definitio.rtf",
#  'data/extracted_docs\\Federal Register_ Final Priorities, Requirements, Definitions, And Selection Criteria-Promise Neighb.rtf',
#  'data/extracted_docs\\Federal Register_ Final Priority and Definitions-State Personnel Development Grants Pages 45525 - 45.rtf',
#  'data/extracted_docs\\Federal Register_ Proposed Priorities, Requirements, Definitions, and Selection Criteria-Promise Nei.rtf',
#  'data/extracted_docs\\Federal Register_ Proposed Priority and Definitions-State Personnel Development Grants Pages 22972 -.rtf',
#  'data/extracted_docs\\Federal Reserve Bank of Minneapolis _ Examining Teacher Turnover in Early Care and Education.rtf',
#  'data/extracted_docs\\Federal Reserve Bank of Minneapolis _ What Drives the Cost of High-Quality Early Care and Education_.rtf',
#  "data/extracted_docs\\Ferenczy_ Should some students repeat this school year_ Ontario doesn't give families a choice(2).rtf",
#  "data/extracted_docs\\Ferenczy_ Should some students repeat this school year_ Ontario doesn't give families a choice.rtf",
#  'data/extracted_docs\\Files (100)_doclist.rtf',
#  'data/extracted_docs\\Filling in the Gaps School districts have teaching positions to fill, but the vacancies remain. That.rtf',
#  'data/extracted_docs\\FIRST REPORT ISSUED ON MICHIGAN PARTNERSHIP MODEL OF SCHOOL REFORM.rtf',
#  "data/extracted_docs\\First Study of the Impact of Academisation on Teachers' Pay and Progression to Be Led by Warwick Eco.rtf",
#  'data/extracted_docs\\First-of-its-Kind Professional Development Membership Elevates Early Childhood Education Profession.rtf',
#  'data/extracted_docs\\Five questions with Liberty school board candidates for the April 5 election.rtf',
#  'data/extracted_docs\\Florida education news_ Superintendents, mascots, HB 7069 lawsuit and more.rtf',
#  'data/extracted_docs\\Florida Supreme Court Ruling Anti-Public Education And Pro-Charter Schools.rtf',
#  "data/extracted_docs\\FOR THE LOVE OF MUSIC AND TEACHING Award-winner Horrocks likes being 'big kid in charge'(2).rtf",
#  "data/extracted_docs\\FOR THE LOVE OF MUSIC AND TEACHING Award-winner Horrocks likes being 'big kid in charge'(3).rtf",
#  "data/extracted_docs\\FOR THE LOVE OF MUSIC AND TEACHING Award-winner Horrocks likes being 'big kid in charge'.rtf",
#  'data/extracted_docs\\Ford School of Public Policy_ EPI Report Provides Snapshot of Pandemic Challenges for Early Childhoo.rtf',
#  'data/extracted_docs\\Ford School of Public Policy_ How Build Back Better Would Change Educational Access, Affordability -.rtf',
#  'data/extracted_docs\\Fort Chipewyan school receives provincial funding for modernization project.rtf',
#  "data/extracted_docs\\Fort Chipewyan's community-run school produces 41 graduates after first ful.rtf",
#  "data/extracted_docs\\Fort Chipewyan's community-run school produces 41 graduates after first full academic year.rtf",
#  'data/extracted_docs\\Foster youth in Michigan who worked toward diplomas learned a discouraging truth_ They had no credit.rtf',
#  'data/extracted_docs\\Four reasons why schools are facing crippling shortages.rtf',
#  'data/extracted_docs\\Four St. Louis area school districts looking to voters to approve new schools and upgrades.rtf',
#  'data/extracted_docs\\FOUR WAYS PROFESSIONAL DEVELOPMENT CAN IMMEDIATELY BENEFIT TEACHERS.rtf',
#  'data/extracted_docs\\Freda Deskin Gives 5 Fantastic Reasons to Choose a Charter School Education for Your Child.rtf',
#  'data/extracted_docs\\Friends and colleagues remember Vanderbilt data scientist Ben Lane.rtf',
#  'data/extracted_docs\\From biliteracy to bilingual_ Adams 14 working on plan for English learners.rtf',
#  'data/extracted_docs\\Funding North Carolina Public Schools_ Time for a Change_.rtf',
#  'data/extracted_docs\\FUTURE MATH TEACHERS INSTRUCT, LEARN FROM RURAL SCHOOL CHILDREN.rtf',
#  'data/extracted_docs\\FutureEd Issues Public Comment on DOEd Proposed Rule.rtf',
#  'data/extracted_docs\\Gabriel Dumont Institute Celebrates 40th Anniversary.rtf',
#  'data/extracted_docs\\Gallego, Senator Ben Ray Lujan Introduce Bill to Address Teacher Retention, Recruitment and Shortage.rtf',
#  'data/extracted_docs\\Gates of Vienna News Feed 11_21_2021.rtf',
#  'data/extracted_docs\\Gay Lynn Bennion Utah schools need state support in adapting to the pandemic.rtf',
#  "data/extracted_docs\\GED TEACHER MAKES LIFETIME VOCATION TO 'HELP OTHERS HELP THEMSELVES'.rtf",
#  'data/extracted_docs\\Generation Xchange program unites senior citizens and elementary school students.rtf',
#  'data/extracted_docs\\Getting better all the time.rtf',
#  "data/extracted_docs\\Ginny Reeves's newly released _ Goddard School Memories_ Influence of The Common School Movement_ is.rtf",
#  'data/extracted_docs\\GLOBAL ROUND UP SECTOR WEEKLY_ UNIVERSITY NEWSLETTER OF WEEK-ENDED SEP 11, 2022.rtf',
#  'data/extracted_docs\\Gold Dome Report   Legislative Day 6.rtf',
#  'data/extracted_docs\\Gold Dome Report - February 2020 #6.rtf',
#  'data/extracted_docs\\Gold Dome Report - Legislative Day 18 2022.rtf',
#  'data/extracted_docs\\Gold Dome Report - Legislative Day 18.rtf',
#  'data/extracted_docs\\Gold Dome Report - Legislative Day 34 2022.rtf',
#  'data/extracted_docs\\Gold Dome Report - Legislative Day 34.rtf',
#  'data/extracted_docs\\Gold Dome Report - March 2020 #3.rtf',
#  'data/extracted_docs\\Gov. Cooper Announces Appointments to Boards and Commissions.rtf',
#  "data/extracted_docs\\Gov. Reynolds_ Iowa 's Teacher Leadership System Shows Positive Results.rtf",
#  'data/extracted_docs\\Government seeks to expedite the release of political prisoners.rtf',
#  'data/extracted_docs\\GOVERNOR COOPER ANNOUNCES APPOINTMENTS TO BOARDS AND COMMISSIONS AUG. 3, 2020.rtf',
#  "data/extracted_docs\\Governor Hutchinson nonplussed by lawmakers' dodge on teacher raises, but won't force the issue(2).rtf",
#  "data/extracted_docs\\Governor Hutchinson nonplussed by lawmakers' dodge on teacher raises, but won't force the issue.rtf",
#  'data/extracted_docs\\Govt lists 17 grounds to validate teachers(2).rtf',
#  'data/extracted_docs\\Govt lists 17 grounds to validate teachers.rtf',
#  'data/extracted_docs\\Greene County district, unable to find a science teacher, shifts to online classroom.rtf',
#  'data/extracted_docs\\Greenville County Schools Launches New Partnership to Support District Efforts to Improve Teacher Re.rtf',
# ...
#  'data/extracted_docs\\Pandemic prompts more teachers to consider early retirement or new career.rtf',
#  "data/extracted_docs\\Paralists Clean Prep a 9 from UNAM... but they don't deliver the campus.rtf",
#  'data/extracted_docs\\Parcel Tax Team Sits Down to Talk As Campaign Roars into Action Down the Quick Stretch - Part I.rtf',
#  'data/extracted_docs\\PARENTS HOPE FOR BETTER LEARNING CONDITIONS AS SPOKANE MONTESSORI SCHOOL LOSES STATUS 2019 change le.rtf',
#  'data/extracted_docs\\Parents, students petition Shelby County Schools board to investigate Southwest Early College High S.rtf',
#  'data/extracted_docs\\Park County teachers set one-week strike deadline.rtf',
#  'data/extracted_docs\\Paul Tough vs. the College Board.rtf',
#  'data/extracted_docs\\Pay Raises and Pandemic Bonuses_ Can They Keep Teachers in Classrooms_(2).rtf',
#  'data/extracted_docs\\Pay Raises and Pandemic Bonuses_ Can They Keep Teachers in Classrooms_.rtf',
#  'data/extracted_docs\\PEABODY-LED RESEARCH REPORT SHEDS LIGHT ON IMPACT OF EFFECTIVE SCHOOL LEADERSHIP ON STUDENT LEARNING.rtf',
#  'data/extracted_docs\\PED official_ Solution to teacher shortage sitting in classroom.rtf',
#  'data/extracted_docs\\Penn State-Harrisburg_ $1.2 Million NSF Grant Awarded to Help Recruit and Retain Diverse Math Teache.rtf',
#  'data/extracted_docs\\Penn State_ Recent Doctoral Program Graduate Examines Retention of New Teachers.rtf',
#  'data/extracted_docs\\Pennsylvania aims to reverse decline in new teachers, diversify K-12 workforce.rtf',
#  'data/extracted_docs\\Pennsylvania State University _ National Science Foundation Awards More Than $1M to Behrend Research.rtf',
#  "data/extracted_docs\\PERSPECTIVES Teacher shortages due to hiring There's little evidence of educators quitting in droves.rtf",
#  'data/extracted_docs\\Philly education advocates weigh in on new city schools chief Tony Watlington Sr.rtf',
#  'data/extracted_docs\\Point of View_ Rural America Needs STEM Education.rtf',
#  'data/extracted_docs\\Policy analysts_ Claims of impending Michigan teacher shortage overstated.rtf',
#  "data/extracted_docs\\Politics professor MATTHEW GOODWIN reveals why a book about the rise of France 's elite-hating Yello.rtf",
#  "data/extracted_docs\\POOL RULES Little People's Audrey Roloff's kids 'graduate' swim lessons after she's RIPPED for letti.rtf",
#  'data/extracted_docs\\Poor Working Conditions Widespread In Charter Schools.rtf',
#  'data/extracted_docs\\Portage teachers seek contract resolution.rtf',
#  'data/extracted_docs\\Poverty in China_ a personal encounter - part two.rtf',
#  'data/extracted_docs\\Prepare teachers to educate Black, Brown students.rtf',
#  'data/extracted_docs\\Principal of coveted Queens gifted school leaving mid-year.rtf',
#  'data/extracted_docs\\Principal shortages hamper country_s efforts to provide quality educational opportunities for studen.rtf',
#  'data/extracted_docs\\Priorities, Requirements, Definitions, and Selection Criteria_ State Personnel Development Grants.rtf',
#  'data/extracted_docs\\Priority and Definitions_ State Personnel Development Grants.rtf',
#  'data/extracted_docs\\PRIVATE COMPANIES WEEKLY_ NEW YORK ( USA ) NEWSLETTER OF WEEK-ENDED AUG 14, 2022.rtf',
#  'data/extracted_docs\\Privately-Operated Charter Schools Continue to Fail and Close.rtf',
#  "data/extracted_docs\\PROFESSOR'S RESEARCH ON THE GENDER EFFECTS OF COVID-19 INFORMS POLICY AT FEDERAL, STATE LEVEL(2).rtf",
#  "data/extracted_docs\\PROFESSOR'S RESEARCH ON THE GENDER EFFECTS OF COVID-19 INFORMS POLICY AT FEDERAL, STATE LEVEL.rtf",
#  'data/extracted_docs\\PROGRAM GIVES STUDENTS FIRSTHAND EXPERIENCE IN CREATING EDUCATION START-UPS.rtf',
#  'data/extracted_docs\\PROGRAM TO RETAIN TEACHERS EXTENDED PILOT TO RUN THROUGH 2025-26 SCHOOL YEAR UW-MADISON _ SCHOOL OF.rtf',
#  'data/extracted_docs\\Promise Neighborhoods Program_ Final Priorities, Requirements, Definitions, and Selection Criteria.rtf',
#  'data/extracted_docs\\Promise Neighborhoods Program_ Proposed Priorities, Requirements, Definitions, and Selection Criteri.rtf',
#  'data/extracted_docs\\Proposed overhaul of the North Carolina teacher pay structure garners mixed reactions.rtf',
#  'data/extracted_docs\\Pseudo-Socialist Bernie Sanders Finally Opposes Charter Schools.rtf',
#  'data/extracted_docs\\Public Personnel Management Journal Issues Research Articles in June 2021 Edition.rtf',
#  'data/extracted_docs\\Public Schools Should Conduct Exit Interviews with Teachers and then Post that info on the Website.rtf',
#  'data/extracted_docs\\Push for weaker requirements for reading teachers quickly stalls.rtf',
#  'data/extracted_docs\\Push gov to OK education funds Dems want to up special-ed aid.rtf',
#  "data/extracted_docs\\Push to diversify state's teacher workforce.rtf",
#  'data/extracted_docs\\Pushing Too Hard_ Unattainable Organizational Goals and Frontline Employee Turnover(2).rtf',
#  'data/extracted_docs\\Pushing Too Hard_ Unattainable Organizational Goals and Frontline Employee Turnover.rtf',
#  'data/extracted_docs\\Q1 2020 Internationella Engelska Skolan I Sverige Holdings II AB Earnings Call - Final.rtf',
#  'data/extracted_docs\\Q2 2019 Rise Education Cayman Ltd Earnings Call - Final.rtf',
#  'data/extracted_docs\\Q2 2021 Stride Inc Earnings Call - Final.rtf',
#  'data/extracted_docs\\Q3 2020 Educational Development Corp Earnings Call - Final.rtf',
#  'data/extracted_docs\\Q4 2021 Instructure Holdings Inc Earnings Call - Final.rtf',
#  'data/extracted_docs\\Quality of life factors into ND job market.rtf',
#  'data/extracted_docs\\QUINTA BRUNSON _ABBOTT ELEMENTARY_.rtf',
#  'data/extracted_docs\\Racial Representation and Socialization in Bureaucratic Organizational Structures.rtf',
#  "data/extracted_docs\\Raptors head coach launches Nick Nurse Foundation to support children's programs Raptors coach launc.rtf",
#  'data/extracted_docs\\RCS BOE meets; budget discussed.rtf',
#  'data/extracted_docs\\Reader letters_ First Australia Day had different date.rtf',
#  'data/extracted_docs\\Reading wars fail our kids.rtf',
#  "data/extracted_docs\\Ready to 'make a change,' 600 new Memphis teachers excited for the first day of school.rtf",
#  'data/extracted_docs\\Reality of teaching in Phila. schools.rtf',
#  'data/extracted_docs\\Recall petitions submitted against two Colorado school board members.rtf',
#  'data/extracted_docs\\Recent editorials from Texas newspapers.rtf',
#  "data/extracted_docs\\Recent efforts to combat teacher shortages don't address the realproblems.rtf",
#  'data/extracted_docs\\Record number of public employees quit in Wisconsin last year.rtf',
#  'data/extracted_docs\\Recruitment Opportunities Dry Up, Teachers Back Out As Districts Look to Hire for Fall.rtf',
#  'data/extracted_docs\\Reform Adoption in a Postcollective Bargaining Governance Environment.rtf',
#  "data/extracted_docs\\Registration open for Iowa City Community School District 's new school_ ICCSD Online.rtf",
#  "data/extracted_docs\\Reinvest in Marquette's College of Education, don't dismantle it.rtf",
#  'data/extracted_docs\\REL Study_ Teacher Turnover and Access to Effective Teachers.rtf',
#  "data/extracted_docs\\Relationship of Teachers' Empowerment and Organizational Commitment at Secondary School Level in Pun.rtf",
#  'data/extracted_docs\\RELEASE_ New CAP Proposal Would Improve Working Conditions for Teachers, Increase Educator Retention.rtf',
#  'data/extracted_docs\\Religions Journal Issues Research Articles in September 2021 Edition.rtf',
#  'data/extracted_docs\\Remote West Virginia School District Connects Students to Virtual Classroom Proximity Learning Inc.rtf',
#  'data/extracted_docs\\Renewing Phalen contract, IPS gives a vote of confidence to its first innovation school.rtf',
#  'data/extracted_docs\\Rep. Bush Announces Distribution of American Rescue Plan Funding for Missouri Schools and Students.rtf',
#  'data/extracted_docs\\Rep. Foxx_ Head Start Mask Mandates Harm Children.rtf',
#  'data/extracted_docs\\Rep. Gallego, Sen. Ray Lujan Introduce Bill to Address Teacher Retention, Recruitment and Shortage C.rtf',
#  'data/extracted_docs\\Rep. Lucas Bill to Improve STEM Education in Rural Schools Passes House(2).rtf',
#  'data/extracted_docs\\Rep. Lucas Bill to Improve STEM Education in Rural Schools Passes House.rtf',
#  'data/extracted_docs\\Rep. Lucas Joins Colleagues Advocating Support for 4-H, Youth Mentorship Organizations During COVID-(2).rtf',
#  'data/extracted_docs\\Rep. Lucas Joins Colleagues Advocating Support for 4-H, Youth Mentorship Organizations During COVID-.rtf',
#  'data/extracted_docs\\Rep. Lucas_ Bipartisan Bill Will Improve STEM Education in Rural Areas(2).rtf',
#  'data/extracted_docs\\Rep. Lucas_ Bipartisan Bill Will Improve STEM Education in Rural Areas.rtf',
#  "data/extracted_docs\\Rep. McAdams' Bipartisan STEM Education Bill Passes the House.rtf",
#  'data/extracted_docs\\Rep. Schiff, Sen. Booker Introduce Legislation to Boost Teacher Compensation.rtf',
#  'data/extracted_docs\\Report confirms need for reforms in Newport schools , more options for parents(2).rtf',
#  'data/extracted_docs\\Report confirms need for reforms in Newport schools , more options for parents.rtf',
#  'data/extracted_docs\\REPORT NOTES 3 AREAS TO IMPROVE INCLUDING SUPPORT FOR STAFF, COMMUNICATION ONE CITY SCHOOLS.rtf',
#  'data/extracted_docs\\REPORT SHOWS BRIGHT SPOTS DESPITE ISSUES FACING PPS.rtf',
#  'data/extracted_docs\\Reports from Johns Hopkins University Highlight Recent Findings in Pediatrics (Why Are They Leaving_.rtf',
#  'data/extracted_docs\\Reports Outline Education Study Findings from University of Melbourne (Teacher Perspectives When Lea.rtf',
#  "data/extracted_docs\\Report_ Detroit students leave the city for schools that aren't much better.rtf",
#  'data/extracted_docs\\REPORT_ DISTRICT FACING SYSTEMIC PROBLEMS CITY PUBLIC SCHOOLS AT A CRITICAL JUNCTURE.rtf',
#  'data/extracted_docs\\Representative Bureaucracy, Environmental Turbulence, and Organizational Performance.rtf',
#  'data/extracted_docs\\Representative Bureaucracy, Institutional Support, and Clientele Need_ The Case of Undocumented Stud.rtf',
#  'data/extracted_docs\\Reps. Hayes, Schiff, Takano, Larson, Sen. Booker Lead Legislation to Boost Teacher Pay.rtf',
#  'data/extracted_docs\\Reps. Johnson, Lucas Bill Will Improve STEM Education in Rural Communities.rtf',
#  'data/extracted_docs\\Reps. Lucas and Johnson Bill Will Improve STEM Education in Rural Communities.rtf',
#  'data/extracted_docs\\Reps. Lucas, Johnson Bill Will Improve STEM Education in Rural Communities.rtf',
#  "data/extracted_docs\\RESEARCH LEADING WAY TO CONNECTICUT SCHOOLS' COVID RECOVERY.rtf",
#  'data/extracted_docs\\RESEARCH SHOWS RENTAL ASSISTANCE REDUCES HARDSHIP AND PROVIDES PLATFORM TO EXPAND OPPORTUNITY FOR LO.rtf',
#  'data/extracted_docs\\Researchers at George Washington University Publish New Data on COVID-19 (More Than Strength from Wi.rtf',
#  'data/extracted_docs\\RESEARCH_ TEACHER EVALUATIONS WEED OUT LOW-PERFORMING TEACHERS IN URBAN SCHOOLS.rtf',
#  'data/extracted_docs\\RESIDENT MEDICAL LIABILITY LAWSUITS_ WHY AND HOW OFTEN THEY HAPPEN.rtf',
#  "data/extracted_docs\\Rethink Ed Supports Educators Nationwide With Free Well-Being Supports Rethink 's Summer of Self hel.rtf",
#  'data/extracted_docs\\Rice Receives NSF Grant to Boost STEM Education.rtf',
#  'data/extracted_docs\\Rice University _ Texas Teacher Shortage Tackled by Rice Certification Plan.rtf',
#  'data/extracted_docs\\Rise Shine_ Before fatal stabbing, Bronx school was warned student had a knife.rtf',
#  'data/extracted_docs\\Rise Shine_ Charter, black, and special needs students more likely to be held back by Michigan readi.rtf',
#  "data/extracted_docs\\Rise Shine_ Here's how much textbook fees can cost Indiana families at different districts.rtf",
#  'data/extracted_docs\\Rise Shine_ Many Detroit students leave the city to attend school. Do they benefit_.rtf',
#  'data/extracted_docs\\Rise Shine_ Memphis teen honored for work encouraging women of color to pursue politics.rtf',
#  'data/extracted_docs\\Rise Shine_ New Aurora charter school in jeopardy due to low enrollment.rtf',
#  "data/extracted_docs\\Rise Shine_ NYC's school improvement strategy is still murky.rtf",
#  'data/extracted_docs\\Rise Shine_ Roaring Fork district among those affected by Pearson data breach.rtf',
#  'data/extracted_docs\\Rise Shine_ Roncalli High School grad calls Catholic LGBTQ students to action.rtf',
#  "data/extracted_docs\\Rise Shine_ What Gov. Polis' proposed budget would do for education.rtf",
#  "data/extracted_docs\\Rise Shine_ Why Nashville's two state-run charter schools are outpacing peers.rtf",
#  'data/extracted_docs\\Roadblocks to transferring schools.rtf',
#  'data/extracted_docs\\Rosen, Wicker Introduce Bipartisan Legislation to Improve Access to STEM Education in Rural Areas Se.rtf',
#  'data/extracted_docs\\Rosen, Wicker Introduce Bipartisan Legislation to Improve Access to STEM Education in Rural Areas.rtf',
#  'data/extracted_docs\\Rosen, Wicker, Cornyn, Hassan Re-Introduce Bipartisan Legislation to Improve Access to STEM Educatio(2).rtf',
#  'data/extracted_docs\\Rosen, Wicker, Cornyn, Hassan Re-Introduce Bipartisan Legislation to Improve Access to STEM Educatio.rtf',
#  'data/extracted_docs\\Rural America Needs STEM Education Point of View_ Rural America Needs STEM Education Rep. Frank Luca.rtf',
#  'data/extracted_docs\\Rural school division sees small enrolment increase.rtf',
#  'data/extracted_docs\\Rural schools embrace new licensing rules to battle teacher shortage.rtf',
#  'data/extracted_docs\\Rural schools find creative solutions to teacher shortage.rtf',
#  "data/extracted_docs\\Rural schools have a teacher shortage. Why don't people who live there, teach there_.rtf",
#  'data/extracted_docs\\Rural Schools Rely on Intangibles and Harder Work to Sustain Adequate Education.rtf',
#  'data/extracted_docs\\Rural setting, COVID widen region_s teacher gap 84% of districts in east-central Illinois report sho.rtf',
#  'data/extracted_docs\\RURAL STEM EDUCATION ACT; Congressional Record Vol. 166, No. 160 (House of Representatives - Septemb.rtf',
#  'data/extracted_docs\\RURAL TEXAS SCHOOL DISTRICTS AND LAWMAKERS SHOULD FOCUS ON RECRUITMENT AND RETENTION.rtf',
#  "data/extracted_docs\\SACKS_ Conservatives Get It Wrong On Black Poverty And The Public School System - Here's Why.rtf",
#  'data/extracted_docs\\Sacred Heart University Bridge Portal.rtf',
#  'data/extracted_docs\\SAD BUT TRUANT Attendance problems plaguing Philly, as one school reveals.rtf',
#  'data/extracted_docs\\SAFER ACCESS TO ESSENTIAL PUBLIC SERVICES PROGRAM.rtf',
#  'data/extracted_docs\\Safety first for supermarket foodservice workers(2).rtf',
#  'data/extracted_docs\\Safety first for supermarket foodservice workers.rtf',
#  'data/extracted_docs\\Same classroom, different salaries_ Special education pre-K teachers earn dramatically less than tha.rtf',
#  'data/extracted_docs\\San Francisco Mayor Breed Announces $10M in Stipends for San Francisco Educators.rtf',
#  'data/extracted_docs\\San Francisco Mayor Breed Announces Distribution of $30 Million for Early Childhood Educators.rtf',
#  'data/extracted_docs\\San Francisco Mayor London Breed and Community Partners Provide Backpacks for Students.rtf',
#  'data/extracted_docs\\San Francisco Mayor London Breed Signs City Budget With Significant Investments in Housing, Homeless.rtf',
#  "data/extracted_docs\\Saskatoon , Chinook school divisions expect cuts after 'another difficult' budget(2).rtf",
#  "data/extracted_docs\\Saskatoon , Chinook school divisions expect cuts after 'another difficult' budget.rtf",
#  "data/extracted_docs\\Scenes from Chicago Public Schools' first back-to-school bash full of free stuff.rtf",
#  'data/extracted_docs\\School attendance increases as students gain confidence and skills in Russian Mission outdoors progr.rtf',
#  'data/extracted_docs\\School board approves plans to improve East and West Lee.rtf',
#  'data/extracted_docs\\School board wants gains in reading With most third graders not at grade level, new monitoring set.rtf',
#  'data/extracted_docs\\School Discipline Policies, Perceptions of Justice, and In-School Delinquency.rtf',
#  ...]

# %%
def read_rtf_to_text(file_name):
    '''
    read one file by its name
    :param file_name:
    :return: plain text
    '''
    with open(file_name, 'r') as file:
        file_text = file.read()
        text = rtf_to_text(file_text, errors="ignore")
    return text

# %%
articles_list = []
for name in file_name:
    article = read_rtf_to_text(name)
    articles_list.append(article)

# %%
# Construct a dataframe
article_names = [s.replace('data/extracted_docs\\', '').replace('.rtf', '').replace('_', '') for s in file_name]
articles_df = pd.DataFrame()
articles_df["text"] = articles_list
articles_df["title"] = article_names

#find load_date and newsoutlet in population
date = []
outlet_column = []

# %%
for article in articles_df["text"]:
    date.append(article.partition("Load-Date:")[2].replace("End of Document", "").strip())
articles_df["date"] = date

# %%
for article in articles_df["text"]:
    outlet = article.split('\n', 6)[5]
    outlet_column.append(outlet)
articles_df["outlet"] = outlet_column

# %%
cleaned_texts = []
for article in articles_df["text"]:
    cleaned_text = article.replace('\n', '').replace('\r', '').replace('\xa0', '')
    cleaned_texts.append(cleaned_text)
articles_df["text"] = cleaned_texts

# %%
def mdy_to_ymd(d):
    '''
    Converts a string date to YYYY-MM-DD format
    '''
    return datetime.datetime.strptime(d, '%B %d, %Y').strftime('%Y-%m-%d')

# %%
converted_dates = []
index=0
for article in articles_df["date"]:
    #print(index)
    if article != '':
        # Convert string text to valid ISO 8601 format
        formatted_date = mdy_to_ymd(article)
        # Convert to datetime object
        converted_date = datetime.date.fromisoformat(formatted_date)
    else:
        converted_date = np.nan
    converted_dates.append(converted_date)
    #index=index+1
articles_df["datetime_obj"] = converted_dates

# %%
articles_df["datetime_obj"].dtypes
# Out:
# dtype('O')

# %%
after_covid = []
covid_date = datetime.date(2020, 3, 11)
for i in list(articles_df.index):
    #print(i)
    if articles_df["date"][i] != '':
        if articles_df["datetime_obj"][i] < covid_date:
            after_covid.append(0)
        else:
            after_covid.append(1)
    else:
        after_covid.append(np.nan)
articles_df["covid"] = after_covid

# %%
articles_df.covid.value_counts()
# Out:
# 1.0    922
# 0.0    425
# Name: covid, dtype: int64

# %%
articles_df
# Out:
#                                                    text  \
# 0     'A momentous decision': What the resolution of...
# 1     'A nice uplift for the community'; Fort Chipew...
# 2     'A societal crisis': Does this UMKC program ha...
# 3     'Abbott Elementary'; School veteran shares wha...
# 4     'FALL INTO TEACHING' EVENT CELEBRATES BOOK REL...
# ...                                                 ...
# 1498  Youngkin outlines steps to address teacher sho...
# 1499  : 'It's been a while since we've had this many...
# 1500  : WARREN, CHILD CARE PROVIDER, SMALL BUSINESS ...
# 1501  "Mixed" teaching: the new normality of higher ...
# 1502  "They will not be the marked generation, but t...
#
#                                                   title               date  \
# 0     'A momentous decision' What the resolution of ...       May 14, 2020
# 1     'A nice uplift for the community'; Fort Chipew...   November 7, 2019
# 2     'A societal crisis' Does this UMKC program hav...   December 7, 2021
# 3     'Abbott Elementary' School veteran shares what...   December 7, 2021
# 4     'FALL INTO TEACHING' EVENT CELEBRATES BOOK REL...  September 6, 2019
# ...                                                 ...                ...
# 1498  Youngkin outlines steps to address teacher sho...  September 1, 2022
# 1499   'It's been a while since we've had this many ...     August 8, 2021
# 1500   WARREN, CHILD CARE PROVIDER, SMALL BUSINESS O...     April 28, 2022
# 1501  Mixed teaching the new normality of higher edu...     March 11, 2021
# 1502  They will not be the marked generation, but th...  September 1, 2020
#
#                                     outlet datetime_obj  covid
# 0                           Newstex Blogs    2020-05-14    1.0
# 1                      Fort McMurray Today   2019-11-07    0.0
# 2                           Newstex Blogs    2021-12-07    1.0
# 3                The Philadelphia Inquirer   2021-12-07    1.0
# 4                              US Fed News   2019-09-06    0.0
# ...                                    ...          ...    ...
# 1498  The Breeze: James Madison University   2022-09-01    1.0
# 1499                        Newstex Blogs    2021-08-08    1.0
# 1500                   States News Service   2022-04-28    1.0
# 1501       CE Noticias Financieras English   2021-03-11    1.0
# 1502       CE Noticias Financieras English   2020-09-01    1.0
#
# [1503 rows x 6 columns]

# %%
#os.makedirs('data', exist_ok=True)  
articles_df.to_csv('data/articles_df.csv', index=False)
